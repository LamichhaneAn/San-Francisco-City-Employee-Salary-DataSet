# %% [markdown]
# Data Analysis With Python Pandas | San Francisco City Employee Salary  DataSet

# %%
import pandas as pd

data = pd.read_csv("Salaries.csv")
data
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9260\2428758899.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# Display Top 10 Rows of the Dataset

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# 2.Check Last 10 Rows of the Dataset

# %%
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# 3. Find the shape of our Dataset(Number of Rows and Number of Columns)

# %%
data.shape
# Out:
# (148654, 13)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 148654
# Number of Columns 13

# %% [markdown]
# 4. Getting Information About out Dataset Like Total Number Rows,
# Total Number of Columns, Datatypes of Each Column and Memory Requirement.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# 5. Check Null Values in the Dataset

# %% [markdown]
# if we do data.isnull() boolean table is generate

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# 6. Drop ID, Notes, Agency and Status Columns

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# # axis = 1 means drop the column
#
#
# data = data.drop(["Id", "Note", "Agency", "Status"], axis=1)
# data

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %% [markdown]
# 7. Get Overall Statistics About the Dataframe:

# %%
data.describe(include = "all")
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %% [markdown]
# 8. Find Occurrence of the Employee Names(Top 5)

# %%
top_5_employees = data["EmployeeName"].value_counts().head(5)
top_5_employees
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# 9. Find the Number of Unique Job Titles:

# %%
unique_job_title = data["JobTitle"].nunique()
print("The unique Job title is", unique_job_title)
# Out:
# The unique Job title is 2159

# %% [markdown]
# 10. Total Number of Job Titles Contain Captain:

# %%
data["JobTitle"]
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
data[data["JobTitle"].str.contains("CAPTAIN", case = False)]
# Out:
#               EmployeeName                               JobTitle    BasePay  \
# 1             GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2           ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)    99722.0
# 17          SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 22           GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION  140546.88
# ...                    ...                                    ...        ...
# 116604   Gregory L Stewart              Captain, Fire Suppression   73355.21
# 120867     Michael J Moran                              Captain 3     7660.0
# 122361  Michael V Rolovich              Captain, Fire Suppression        0.0
# 126588    Stephen M Tittel                              Captain 3   68491.89
# 132232     Jeanne M Seyler              Captain, Fire Suppression   61039.43
#
# ...

# %%
x = len(data[data["JobTitle"].str.contains("CAPTAIN", case = False)])
print("The total number of Job Title Contain Caption are", x)
# Out:
# The total number of Job Title Contain Caption are 552

# %% [markdown]
# 11. Display all the Employee Names From Fire Department

# %%
data[data["JobTitle"].str.contains("fire", case=False)]["EmployeeName"]
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %% [markdown]
# 12. Find Minimum, Maximum and Average BasePay

# %%
data["BasePay"].describe()
# Out:
# count     148049.0
# unique    109900.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %% [markdown]
# 13. Replace "Not Provided" in EmployeeName Column to NaN

# %%
data["EmployeeName"].replace(to_replace="Not provided",value="Nan")
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  Nan
# 148651                  Nan
# 148652                  Nan
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# 14. Drop the Rows Having 5 Missing Values.

# %%
data[data.isnull().sum(axis=1)==5]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
data.drop(data[data.isnull().sum(axis=1)==5].index, axis=0)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# 15. Find the Job Title of ALBERT PARDINI

# %%
data[data["EmployeeName"]=="ALBERT PARDINI"]["JobTitle"]
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# 16. How much ALBERT PARDINI Make (Include Benefits)?

# %%
data[data["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# 17. Display Name of the Person Having the Highest BasePay

# %%
import pandas as pd

# Load your data
data = pd.read_csv("Salaries.csv")

# Replace "Not Provided" with NaN in the 'BasePay' column
data['BasePay'] = data['BasePay'].replace("Not Provided", np.nan).astype(float)

# Find the highest BasePay value
highest_basepay = data["BasePay"].max()

# Filter the DataFrame to get the row(s) with the highest BasePay
highest_pay_employee = data[data["BasePay"] == highest_basepay]

# Display the name(s) of the person(s) with the highest BasePay
print(highest_pay_employee["EmployeeName"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9260\2947718555.py:4: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Salaries.csv")
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
data[data["BasePay"].max()==data["BasePay"]]["EmployeeName"]
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# 18. FInd the Average BasePay of All Employee  per year

# %%
import pandas as pd

# Load your data
data = pd.read_csv("Salaries.csv")

# Replace "Not Provided" with NaN and convert 'BasePay' to float
data['BasePay'] = data['BasePay'].replace("Not Provided", np.nan).astype(float)

# Group by 'Year' and calculate the mean 'BasePay' for each year
average_basepay_per_year = data.groupby("Year")["BasePay"].mean()

print(average_basepay_per_year)
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9260\4132507432.py:4: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Salaries.csv")

# %% [markdown]
# 19. Find the Average BasePay of all Employee per Job title

# %%
import pandas as pd
import numpy as np

# Load your data
data = pd.read_csv("Salaries.csv")

# Replace "Not Provided" with NaN and convert 'BasePay' to float
data['BasePay'] = data['BasePay'].replace("Not Provided", np.nan).astype(float)

# Group by 'JobTitle' and calculate the mean 'BasePay' for each job title
average_basepay_per_jobtitle = data.groupby("JobTitle")["BasePay"].mean()

print(average_basepay_per_jobtitle)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9260\3593848593.py:5: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Salaries.csv")
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# 20. Find the Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
import pandas as pd
import numpy as np

# Load your data
data = pd.read_csv("Salaries.csv")

# Replace "Not Provided" with NaN and convert 'BasePay' to float
data['BasePay'] = data['BasePay'].replace("Not Provided", np.nan).astype(float)

# Find the average BasePay for employees with the job title "ACCOUNTANT"
average_basepay_accountant = data[data["JobTitle"] == "ACCOUNTANT"]["BasePay"].mean()

print("Average BasePay for ACCOUNTANT:", average_basepay_accountant)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9260\486133961.py:5: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Salaries.csv")
# Average BasePay for ACCOUNTANT: 46643.172

# %% [markdown]
# 21. Find the top 5 most common jobs

# %%
data["JobTitle"].value_counts()
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64

# %% [markdown]
#                                                             **Thank you**
